# %% [markdown]
# # Set up
#
# <a href="https://colab.research.google.com/github/AlisonJD/RTACourse/blob/main/set_up.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# This notebook demonstrates how to mount your Google drive, install the Tinybird CLI and create the required directories.

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=False)

% cd "/content/gdrive/My Drive/Colab Notebooks"
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/My Drive/Colab Notebooks

# %%
import os

# %%
if not os.path.exists('Tinybird'):
    os.makedirs('Tinybird')
% cd Tinybird
# Out:
# /content/gdrive/My Drive/Colab Notebooks/Tinybird

# %%
# !pip install tinybird-cli -q

# %%
# !git clone https://github.com/AlisonJD/RTACourse
# Out:
# Cloning into 'RTACourse'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 10 (delta 2), reused 3 (delta 0), pack-reused 0
# Unpacking objects: 100% (10/10), done.

# %%
# !tb init
# Out:
# ** - /datasources already exists, skipping
# ** - /datasources/fixtures already exists, skipping
# ** - /endpoints already exists, skipping
# ** - /explorations already exists, skipping
# ** - /pipes already exists, skipping

# %%
# !tb auth
# Out:
# Copy the admin token from https://ui.tinybird.co/tokens and paste it here:
# ** Auth successful!
# ** Configuration written to .tinyb file, consider adding it to .gitignore

# %%
% cd Tinybird/RTACourse
# Out:
# /content/gdrive/My Drive/Colab Notebooks/Tinybird/RTACourse

# %%
# !git pull
# Out:
# Updating a844204..8cfccf9
# Fast-forward
#  ClickHouse_Recipes.ipynb                         | 248 +++++++++++++++++++++++
#  Data_Storage_Inside_the_Analytics_Database.ipynb | 177 +++++++++++++++-
#  README.md                                        |   2 +-
#  3 files changed, 420 insertions(+), 7 deletions(-)
#  create mode 100644 ClickHouse_Recipes.ipynb

# %%
# !ls
# Out:
# 3279e-random-compression.png
# 772a0-ts-compression.png
# arrow1.png
# Best_Practices_for_Views.ipynb
# ClickHouse_Recipes.ipynb
# Data_Storage_Inside_the_Analytics_Database.ipynb
# New_York_City_Taxi_Trip_Datasets.ipynb
# README.md
# set_up.ipynb
# Software_and_Hardware.ipynb
# Source_Data_and_Ingestion.ipynb
# Use_the_Right_Database.ipynb
# Why_this_course.ipynb
